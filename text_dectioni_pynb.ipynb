# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahFarmanAli12/text-and-vedio-writeing-detection/blob/main/text_dectioni_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract
import pytesseract
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv2.imread ("/content/6.png")

# %%
plt.imshow(img)

# %%
im2char = pytesseract.image_to_string(img, lang='eng')

# %%
print(im2char)
# Out:
# El Contato de Trabajo
#
# 1. A Al
#
# 5 un acuerdo de voluntaes por el que una de las partes, vabsiador, so compromet|
# untariamente 2 presarsenicos para otra persona, empresa, bajo su drecén y poder de
# rganzacé, cambio de una remuneracén
#
#
#
#
#
# ‘elcin que nace de este conato sera personal, retibulda, por cuent
#
#
#
# jena, volunaia
#
# JID EDM TOS
# (ode contato debe contener, para se vilido ls siguientes elementos
#
# ‘© Consentimlento, Voluntad coincidente de fos contatantes. Las partes estin do acuerdo ¥
# ‘uleren acer ef contate.€l consentinente no debe estar lado por evar, violencia
# intmidacion® 0 dol
#
# 1+ objeto. Asunto sobre el que recaen os derechos yobgaiones dl contrat, es dec, puesto
# e trabajo la remuneracén.€l objeto, a su ver, debe Ser posible, Kit, determinado o
# <eterminabey con contenido patrieria. Se debe poder realiar, ser legal concetoy poder
# medi econdmicamente
#
# ...

# %%
mibox = pytesseract.image_to_boxes(img)
type(mibox)
# Out:
# str

# %%
print(mibox)
# Out:
# E 114 613 118 620 0
# l 119 613 121 620 0
# C 124 613 129 620 0
# o 126 613 131 620 0
# n 130 613 134 618 0
# t 135 613 142 619 0
# a 143 613 147 618 0
# t 147 613 151 618 0
# o 152 613 160 619 0
# d 163 613 167 620 0
# e 168 613 172 618 0
# T 175 612 180 620 0
# r 175 613 180 620 0
# a 181 613 188 618 0
# b 184 612 194 620 0
# a 189 613 198 620 0
# j 199 612 201 618 0
# o 202 613 206 618 0
# 1 49 514 59 542 0
# . 53 523 63 532 0
# A 146 523 154 532 0
# A 215 523 221 532 0
# l 215 523 223 532 0
# 5 57 505 60 510 0
# u 67 505 72 510 0
# n 67 505 77 510 0
# a 84 505 88 512 0
# c 84 505 88 510 0
# u 89 505 97 510 0
# e 92 505 102 512 0
# r 98 505 102 510 0
# d 102 505 112 512 0
# o 103 505 116 512 0
# d 123 505 128 512 0
# e 123 505 132 512 0
# v 139 505 144 512 0
# o 139 505 149 512 0
# l 139 505 155 512 0
# u 151 505 156 512 0
# n 153 505 158 512 0
# t 155 505 165 512 0
# a 160 505 170 512 0
# e 156 505 182 512 0
# s 174 505 182 512 0
# p 190 504 196 510 0
# o 190 504 199 510 0
# ...

# %%
imgH, imgW, _ = img.shape

# %%
img.shape
# Out:
# (651, 466, 3)

# %%
for boxes in mibox.splitlines():
  boxes = boxes.split(' ')
  x, y, w, h = int(boxes[1]), int(boxes[2]), int(boxes[3]), int(boxes[4])
  cv2.rectangle(img, (x, imgH-y), (w, imgH-h), (0,0,255), 3)

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# DEMO FOR VIDEO

# %%
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN

# %%
# Install Tesseract and required packages
# !apt install tesseract-ocr -y
# !pip install pytesseract opencv-python

# Import necessary libraries
import cv2
import pytesseract
import time
from google.colab.patches import cv2_imshow
from google.colab import files

# Upload a video file
uploaded = files.upload()
video_path = list(uploaded.keys())[0]

# Open video
cap = cv2.VideoCapture(video_path)

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video.")
        break

    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # OCR text extraction
    text = pytesseract.image_to_string(gray)

    # Show frame
    cv2_imshow(frame)

    # Print extracted text
    print(f"\n📝 Frame {frame_count} OCR Result:\n{text}\n{'='*60}")

    frame_count += 1
    time.sleep(0.5)  # Simulate video delay

cap.release()
